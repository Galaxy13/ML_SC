# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
axes = fig.add_axes([0, 0, 1, 1])
x = np.arange(0, 10)
y = 2 * x
axes.plot(x, y)

# %%
a = np.linspace(0, 10, 11)
b = a ** 4

# %%
x = np.arange(0, 10)
y = 2 * x

# %%
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1])
axes1.plot(a, b)
axes1.set_xlim(0, 8)
axes1.set_ylim(0, 8000)
axes1.set_xlabel('A')
axes1.set_ylabel('B')
axes1.set_title('Power 0f four')

axes2 = fig.add_axes([1, 0, 1, 1])
axes2.plot(a, b)
axes2.set_xlim(1, 2)
axes2.set_ylim(0, 50)
axes2.set_xlabel('X')
axes2.set_ylabel('Y')
axes2.set_title('Power of 2')
# Out:
# Text(0.5, 1.0, 'Power of 2')

# %%
fig = plt.figure(dpi=200, figsize=(10, 3))

axes1 = fig.add_axes([0, 0, 1, 1])
axes1.plot(a, b)
fig.savefig('new_figure.png', bbox_inches='tight')
