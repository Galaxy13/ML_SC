# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

x = np.linspace(0,11,10)
axes.plot(x,x,label='X v X')
axes.plot(x, x ** 2,label='X v X ** 2')

axes.legend(loc=(0.1,0.85))
