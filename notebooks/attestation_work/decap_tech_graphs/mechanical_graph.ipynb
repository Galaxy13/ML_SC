# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('mech_graph.csv.')
df
# Out:
#                                          Unnamed: 0  шт.
# 0               Кол-во ИМС с повреждённым кристалом   42
# 1  Кол-во ИМС с повреждёнными разварочными выводами   21
# 2                        Кол-во ИМС без повреждений  105

# %%
plt.figure(dpi=300)
cat_plot = sns.histplot(data=df, y='шт.', x='')
